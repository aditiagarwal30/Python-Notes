# %%
import pandas as pd

# %%
df= pd.read_csv("C:\\Users\\devesh\\Desktop\\FL_insurance_sample.csv")

# %%
df.head()
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
df1= pd.read_excel("C:\\Users\\devesh\\Desktop\\ApriltoAug.xls")

# %%
df1.head()
# Out:
#   Unnamed: 0     Unnamed: 1           Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 0      State  Customer code        Customer Name   District  Customer Club
# 1  Rajasthan         102140   BUNTY DISTRIBUTORS      ALWAR       CLUB - E
# 2  Rajasthan         102147      NAMAN MARKETING     JAIPUR       CLUB - D
# 3  Rajasthan         102163      MITTAL AGENCIES     JAIPUR       CLUB - D
# 4  Rajasthan         102166  CHOUHAN ENTERPRISES       KOTA       CLUB - D
#
#             427591267           409948000 Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# 0  April-19 to Aug-19  April-20 to Aug-20      Diff.        NaN         NaN
# 1            22500000            20900000   -1600000        NaN         NaN
# 2            22700000            18200000   -4500000        NaN         NaN
# 3            12250000            15370000    3120000        NaN         NaN
# 4            15350000            14319000   -1031000        NaN         NaN
#
#   Unnamed: 10
# 0         NaN
# 1         NaN
# ...

# %%
 df1.shape
# Out:
# (289, 11)

# %%
df.tail()
# Out:
#        policyID statecode           county  eq_site_limit  hu_site_limit  \
# 36629    404309        FL  PINELLAS COUNTY            0.0        88722.0
# 36630    465875        FL  PINELLAS COUNTY      1297057.5      1297057.5
# 36631    791209        FL  PINELLAS COUNTY       173286.9       173286.9
# 36632    322627        FL  PINELLAS COUNTY      1499781.6      1499781.6
# 36633    398149        FL  PINELLAS COUNTY       373488.3       373488.3
#
#        fl_site_limit  fr_site_limit   tiv_2011    tiv_2012  \
# 36629            0.0        88722.0    88722.0   155065.65
# 36630      1297057.5      1297057.5  1297057.5  1577500.79
# 36631            0.0            0.0   173286.9   205527.97
# 36632            0.0            0.0  1499781.6  1768782.43
# 36633            0.0            0.0   373488.3   596003.67
#
#        eq_site_deductible  hu_site_deductible  fl_site_deductible  \
# 36629                 0.0                 0.0                 0.0
# ...

# %%
df1.tail()
# Out:
#         Unnamed: 0 Unnamed: 1        Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 284  Uttar Pradesh     122925  PRAKASH AGENCIES  AMBEDKAR NAGAR   CLUB - D
# 285    Chattisgarh     123130    BALA JI AGENCY         JASHPUR   CLUB - D
# 286          Delhi     123189       MANAV SALES           DELHI   CLUB - D
# 287            NaN        NaN               NaN             NaN        NaN
# 288            NaN        NaN               NaN             NaN        NaN
#
#        427591267 409948000 Unnamed: 7 Unnamed: 8  Unnamed: 9 Unnamed: 10
# 284  1.36344e+07  10450000   -31.8437        NaN         NaN         NaN
# 285            0   5700000         57        NaN         NaN         NaN
# 286     12055000  11286000      -7.69        NaN         NaN         NaN
# 287          NaN       NaN        NaN        NaN         NaN         NaN
# 288     31540000  32650000        NaN        NaN         NaN         NaN

# %%
df.columns       #accessing all column names
# Out:
# Index(['policyID', 'statecode', 'county', 'eq_site_limit', 'hu_site_limit',
#        'fl_site_limit', 'fr_site_limit', 'tiv_2011', 'tiv_2012',
#        'eq_site_deductible', 'hu_site_deductible', 'fl_site_deductible',
#        'fr_site_deductible', 'point_latitude', 'point_longitude', 'line',
#        'construction', 'point_granularity'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index([ 'Unnamed: 0',  'Unnamed: 1',  'Unnamed: 2',  'Unnamed: 3',
#         'Unnamed: 4',     427591267,     409948000,  'Unnamed: 7',
#         'Unnamed: 8',  'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
  df.tail(10)
# Out:
#        policyID statecode           county  eq_site_limit  hu_site_limit  \
# 36624    827844        FL  PINELLAS COUNTY            0.0        38112.3
# 36625    876385        FL  PINELLAS COUNTY            0.0        18312.3
# 36626    167630        FL  PINELLAS COUNTY            0.0         4522.5
# 36627    241496        FL  PINELLAS COUNTY            0.0         1350.0
# 36628    780814        FL  PINELLAS COUNTY            0.0         9770.4
# 36629    404309        FL  PINELLAS COUNTY            0.0        88722.0
# 36630    465875        FL  PINELLAS COUNTY      1297057.5      1297057.5
# 36631    791209        FL  PINELLAS COUNTY       173286.9       173286.9
# 36632    322627        FL  PINELLAS COUNTY      1499781.6      1499781.6
# 36633    398149        FL  PINELLAS COUNTY       373488.3       373488.3
#
#        fl_site_limit  fr_site_limit   tiv_2011    tiv_2012  \
# 36624            0.0        38112.3    38112.3    52710.45
# ...

# %%
df1.tail(6)
# Out:
#         Unnamed: 0 Unnamed: 1        Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 283  Uttar Pradesh     122912   RAVINSHU AGENCY        GHAZIPUR   CLUB - D
# 284  Uttar Pradesh     122925  PRAKASH AGENCIES  AMBEDKAR NAGAR   CLUB - D
# 285    Chattisgarh     123130    BALA JI AGENCY         JASHPUR   CLUB - D
# 286          Delhi     123189       MANAV SALES           DELHI   CLUB - D
# 287            NaN        NaN               NaN             NaN        NaN
# 288            NaN        NaN               NaN             NaN        NaN
#
#        427591267 409948000 Unnamed: 7 Unnamed: 8  Unnamed: 9 Unnamed: 10
# 283  1.85108e+07   8800000   -97.1078        NaN         NaN         NaN
# 284  1.36344e+07  10450000   -31.8437        NaN         NaN         NaN
# 285            0   5700000         57        NaN         NaN         NaN
# 286     12055000  11286000      -7.69        NaN         NaN         NaN
# 287          NaN       NaN        NaN        NaN         NaN         NaN
# ...

# %%
df["policyID"]
# Out:
# 0        119736
# 1        448094
# 2        206893
# 3        333743
# 4        172534
#           ...
# 36629    404309
# 36630    465875
# 36631    791209
# 36632    322627
# 36633    398149
# Name: policyID, Length: 36634, dtype: int64

# %%
df[["policyID","county"]]
# Out:
#        policyID           county
# 0        119736      CLAY COUNTY
# 1        448094      CLAY COUNTY
# 2        206893      CLAY COUNTY
# 3        333743      CLAY COUNTY
# 4        172534      CLAY COUNTY
# ...         ...              ...
# 36629    404309  PINELLAS COUNTY
# 36630    465875  PINELLAS COUNTY
# 36631    791209  PINELLAS COUNTY
# 36632    322627  PINELLAS COUNTY
# 36633    398149  PINELLAS COUNTY
#
# [36634 rows x 2 columns]

# %%
df.iloc[:5]
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
df1.iloc[:5]
# Out:
#   Unnamed: 0     Unnamed: 1           Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 0      State  Customer code        Customer Name   District  Customer Club
# 1  Rajasthan         102140   BUNTY DISTRIBUTORS      ALWAR       CLUB - E
# 2  Rajasthan         102147      NAMAN MARKETING     JAIPUR       CLUB - D
# 3  Rajasthan         102163      MITTAL AGENCIES     JAIPUR       CLUB - D
# 4  Rajasthan         102166  CHOUHAN ENTERPRISES       KOTA       CLUB - D
#
#             427591267           409948000 Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# 0  April-19 to Aug-19  April-20 to Aug-20      Diff.        NaN         NaN
# 1            22500000            20900000   -1600000        NaN         NaN
# 2            22700000            18200000   -4500000        NaN         NaN
# 3            12250000            15370000    3120000        NaN         NaN
# 4            15350000            14319000   -1031000        NaN         NaN
#
#   Unnamed: 10
# 0         NaN
# 1         NaN
# ...

# %%
df.iloc[:,:3]
# Out:
#        policyID statecode           county
# 0        119736        FL      CLAY COUNTY
# 1        448094        FL      CLAY COUNTY
# 2        206893        FL      CLAY COUNTY
# 3        333743        FL      CLAY COUNTY
# 4        172534        FL      CLAY COUNTY
# ...         ...       ...              ...
# 36629    404309        FL  PINELLAS COUNTY
# 36630    465875        FL  PINELLAS COUNTY
# 36631    791209        FL  PINELLAS COUNTY
# 36632    322627        FL  PINELLAS COUNTY
# 36633    398149        FL  PINELLAS COUNTY
#
# [36634 rows x 3 columns]

# %%
df.iloc[:5,:3]
# Out:
#    policyID statecode       county
# 0    119736        FL  CLAY COUNTY
# 1    448094        FL  CLAY COUNTY
# 2    206893        FL  CLAY COUNTY
# 3    333743        FL  CLAY COUNTY
# 4    172534        FL  CLAY COUNTY

# %%
df[df['point_granularity']==3]
# Out:
#        policyID statecode           county  eq_site_limit  hu_site_limit  \
# 1        448094        FL      CLAY COUNTY      1322376.3     1322376.30
# 3        333743        FL      CLAY COUNTY            0.0       79520.76
# 5        785275        FL      CLAY COUNTY            0.0      515035.62
# 16       580146        FL      CLAY COUNTY            0.0       48115.94
# 18       767862        FL      CLAY COUNTY            0.0       48115.94
# ...         ...       ...              ...            ...            ...
# 36626    167630        FL  PINELLAS COUNTY            0.0        4522.50
# 36627    241496        FL  PINELLAS COUNTY            0.0        1350.00
# 36628    780814        FL  PINELLAS COUNTY            0.0        9770.40
# 36629    404309        FL  PINELLAS COUNTY            0.0       88722.00
# 36632    322627        FL  PINELLAS COUNTY      1499781.6     1499781.60
#
#        fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  \
# ...
