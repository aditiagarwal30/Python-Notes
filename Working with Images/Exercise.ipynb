# %%
from PIL import Image

# %%
words= Image.open('word_matrix.png')

# %%
mask= Image.open('mask.png')

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x28D3D540850>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x28D3D5404F0>

# %%
words.size
# Out:
# (1015, 559)

# %%
mask= mask.resize((1015,559))

# %%
mask.size
# Out:
# (1015, 559)

# %%
mask.putalpha(50)

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x28D3D540490>

# %%
words.paste(mask,(0,0),mask)

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x28D3D540850>
